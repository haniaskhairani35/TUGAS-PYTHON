# %% [markdown]
# <a href="https://colab.research.google.com/github/haniaskhairani35/TUGAS-PYTHON/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
#  coast_bea1.jpg  'New 1'/   nnmodel_scene/   Untitled0.ipynb

# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.optimizers import Adam
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image
from imutils import paths
import numpy as np
import os

# %%
# grab all image paths in the input dataset directory, then initialize
# our list of images and corresponding class labels
print("[INFO] loading images...")
imagePaths = paths.list_images("New 1")
data = []
labels = []

# %%
# loop over our input images
for imagePath in imagePaths:
	# load the input image from disk, resize it to 64x64 pixels, scale
	# the pixel intensities to the range [0, 1], and then update our
	# images list
	image = Image.open(imagePath)
	image = np.array(image.resize((64, 64))) / 255.0
	data.append(image)

	# extract the class label from the file path and update the
	# labels list
	label = imagePath.split(os.path.sep)[-2]
	labels.append(label)

# %%
print(labels)

# %%
# encode the labels, converting them from strings to integers
lb = LabelBinarizer()
labels = lb.fit_transform(labels)

# %%
print(labels)

# %%
# perform a training and testing split, using 75% of the data for
# training and 25% for evaluation
(trainX, testX, trainY, testY) = train_test_split(np.array(data),	np.array(labels), test_size=0.25)
print(trainX.shape)
print(testX.shape)

# %%
from keras.layers.core import Flatten
from keras.layers.core import Dense

model = Sequential(
    [
        Flatten(input_shape=(64*64*3,)),
        Dense(100, activation="relu", name="layer1"),
        Dense(16, activation="relu", name="layer2"),
        Dense(16, activation="relu", name="layer3"),
        Dense(3, activation = "softmax", name="layer4"),
    ]
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 12288)             0
# _________________________________________________________________
# layer1 (Dense)               (None, 100)               1228900
# _________________________________________________________________
# layer2 (Dense)               (None, 16)                1616
# _________________________________________________________________
# layer3 (Dense)               (None, 16)                272
# _________________________________________________________________
# layer4 (Dense)               (None, 3)                 51
# =================================================================
# Total params: 1,230,839
# Trainable params: 1,230,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train the model using the Adam optimizer
print("[INFO] training network...")
opt = Adam(lr=1e-3, decay=1e-3 / 50)
model.compile(loss="categorical_crossentropy", optimizer=opt,
	metrics=["accuracy"])
H = model.fit(trainX, trainY, validation_data=(testX, testY), epochs=25, batch_size=32)
# Out:
# [INFO] training network...
# Epoch 1/25
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 21/23 [==========================>...] - ETA: 0s - loss: 1.8126 - accuracy: 0.3229WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
# 23/23 [==============================] - 0s 19ms/step - loss: 1.7679 - accuracy: 0.3352 - val_loss: 1.0931 - val_accuracy: 0.4219
# Epoch 2/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.9639 - accuracy: 0.5746 - val_loss: 0.8742 - val_accuracy: 0.5612
# Epoch 3/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8550 - accuracy: 0.6028 - val_loss: 0.7654 - val_accuracy: 0.6582
# Epoch 4/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.8276 - accuracy: 0.6479 - val_loss: 0.8252 - val_accuracy: 0.5949
# Epoch 5/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.7002 - accuracy: 0.7113 - val_loss: 0.6424 - val_accuracy: 0.7764
# Epoch 6/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6605 - accuracy: 0.7324 - val_loss: 0.6854 - val_accuracy: 0.7215
# Epoch 7/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.6171 - accuracy: 0.7451 - val_loss: 0.7513 - val_accuracy: 0.6245
# Epoch 8/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.5668 - accuracy: 0.7859 - val_loss: 0.6537 - val_accuracy: 0.7300
# Epoch 9/25
# 23/23 [==============================] - 0s 11ms/step - loss: 0.6100 - accuracy: 0.7408 - val_loss: 0.5763 - val_accuracy: 0.7679
# Epoch 10/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5307 - accuracy: 0.7986 - val_loss: 0.5566 - val_accuracy: 0.7975
# Epoch 11/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5222 - accuracy: 0.8070 - val_loss: 0.7051 - val_accuracy: 0.7426
# Epoch 12/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5873 - accuracy: 0.7803 - val_loss: 0.6678 - val_accuracy: 0.7004
# Epoch 13/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5017 - accuracy: 0.8099 - val_loss: 0.5558 - val_accuracy: 0.7553
# Epoch 14/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4792 - accuracy: 0.8099 - val_loss: 0.6769 - val_accuracy: 0.7342
# Epoch 15/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4835 - accuracy: 0.8127 - val_loss: 0.6108 - val_accuracy: 0.7722
# Epoch 16/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5029 - accuracy: 0.7803 - val_loss: 0.6880 - val_accuracy: 0.7426
# Epoch 17/25
# 23/23 [==============================] - 0s 13ms/step - loss: 0.4556 - accuracy: 0.8183 - val_loss: 0.5720 - val_accuracy: 0.7764
# Epoch 18/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4374 - accuracy: 0.8394 - val_loss: 0.6246 - val_accuracy: 0.7553
# Epoch 19/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4160 - accuracy: 0.8507 - val_loss: 0.5594 - val_accuracy: 0.7890
# Epoch 20/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4169 - accuracy: 0.8408 - val_loss: 0.7740 - val_accuracy: 0.6709
# Epoch 21/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4037 - accuracy: 0.8620 - val_loss: 0.8489 - val_accuracy: 0.6709
# Epoch 22/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5275 - accuracy: 0.7817 - val_loss: 0.7455 - val_accuracy: 0.7046
# Epoch 23/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.4165 - accuracy: 0.8380 - val_loss: 0.5601 - val_accuracy: 0.7975
# Epoch 24/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3750 - accuracy: 0.8704 - val_loss: 0.5538 - val_accuracy: 0.7975
# Epoch 25/25
# 23/23 [==============================] - 0s 12ms/step - loss: 0.3337 - accuracy: 0.9014 - val_loss: 0.6216 - val_accuracy: 0.7384

# %%
import matplotlib.pyplot as plt

print(H.history.keys())
# summarize history for accuracy
plt.plot(H.history['accuracy'])
plt.plot(H.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# evaluate the network
print("[INFO] evaluating network...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),
	predictions.argmax(axis=1), target_names=lb.classes_))
# Out:
# [INFO] evaluating network...
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (None, 64, 64, 3).
#               precision    recall  f1-score   support
#
#        coast       0.63      0.91      0.75        86
#       forest       0.88      0.81      0.84        79
#      highway       0.80      0.46      0.58        72
#
#     accuracy                           0.74       237
#    macro avg       0.77      0.73      0.72       237
# weighted avg       0.77      0.74      0.73       237

# %%
model.save('nnmodel_scene')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: nnmodel_scene/assets

# %%
import cv2
import matplotlib.pyplot as plt
image1='coast_bea1.jpg'

# %%
img_array = cv2.imread(image1)
plt.imshow(img_array)
plt.show()
# print(type(img_array))

# %%
image_testing = Image.open('coast_bea1.jpg')
image_testing = np.array(image_testing.resize((64, 64))) / 255.0
image_testing.shape
# Out:
# (64, 64, 3)

# %%
image_testing = np.expand_dims(image_testing, axis=0)
print(image_testing.shape)
# Out:
# (1, 64, 64, 3)

# %%
output = model.predict(image_testing, 1)
print(output)
print(lb.classes_[output.argmax(axis=1)])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 12288) for input Tensor("flatten_input:0", shape=(None, 12288), dtype=float32), but it was called on an input with incompatible shape (1, 64, 64, 3).
# [[0.9777079  0.00124899 0.02104303]]
# ['coast']
